# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df =pd.read_csv('reportSch.csv')
df
# Out:
#           AttendanceDate AttendanceTime AttendanceType CourseCode Section  \
# 0    2024-09-14T00:00:00       01-02 PM              L    EACC210   01QSK
# 1    2024-09-14T00:00:00       01-02 PM              L    EACC210   01USS
# 2    2024-09-14T00:00:00       01-02 PM              L    EACC510   01QSL
# 3    2024-09-14T00:00:00       01-02 PM              L    ECAP470   02DAJ
# 4    2024-09-14T00:00:00       01-02 PM              L    EECO105   02UBE
# ..                   ...            ...            ...        ...     ...
# 616  2024-09-15T00:00:00       12-01 PM              P    ECAP444   01DAN
# 617  2024-09-15T00:00:00       12-01 PM              P    ECAP615   02DAJ
# 618  2024-09-15T00:00:00       12-01 PM              P    ECAP777   01DAH
# 619  2024-09-15T00:00:00       12-01 PM              P    ECAP777   01DSH
# 620  2024-09-15T00:00:00       12-01 PM              P    ECAP784   02DAF
#
#      StudentGroup  TeacherLogin      ParentDiscipline        EmployeeName  \
# ...

# %%
df['AttendanceType'].value_counts()
# Out:
# AttendanceType
# L    513
# P    108
# Name: count, dtype: int64
